# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the data in the npy file
base_path = r"E:\SBME\Graduation_Project\Datasets\Simulated_data\merged"
data = np.load(base_path + r"\real_real_2025-05-13-03-20-09-093567.npy")
# visualize the data
# data = data[:, :, 1]
unique_values = np.unique(data)

for value in unique_values:
    mask = (data == value)  # Create a mask for the current unique value
    plt.imshow(mask, cmap='gray')
    plt.title(f"Mask for value: {value}")
    plt.show()
# plt.imshow(data, cmap='gray')
# plt.show()
# print the unique values in the data
print(np.unique(data))
print(data.shape)
# Out:
# [  0  30  60 100]
# (128, 128)
