# %%
import nibabel as nib
import numpy as np
import os

# %% [markdown]
# ### CHANGE THE BASE DIRECTORY WITH YOUR CORRECT PATH OF THE FOLDER THAT CONTAINS ALL RESAMPLED DATA

# %%
# Define the base directory containing patient folders
base_directory = r'D:\Studying\Fourth year\GP\Datasets\All Data Resampled'

# %%
# Loop over each subfolder in the base directory
for subfolder in os.listdir(base_directory):
    subfolder_path = os.path.join(base_directory, subfolder)

    # Check if the path is a directory
    if os.path.isdir(subfolder_path):
        # Loop over each patient folder in the subfolder
        for patient_folder in os.listdir(subfolder_path):
            patient_path = os.path.join(subfolder_path, patient_folder)

            # Check if the path is a directory (to avoid files)
            if os.path.isdir(patient_path):
                print(f'Processing patient: {patient_folder}')
                
                # Define the path for the images
                nifti_file = os.path.join(patient_path, 'Images', f'{patient_folder}.nii.gz')
                
                # Load the NIfTI image file
                img = nib.load(nifti_file)
                img_data = img.get_fdata()

                # Check if the "Contours" folder exists
                contour_exists = os.path.exists(os.path.join(patient_path, 'Contours'))
                
                # If the "Contours" folder exists, load the mask data
                if contour_exists:
                    masked_file = os.path.join(patient_path, 'Contours', f'{patient_folder}.nii.gz')
                    masked_img = nib.load(masked_file)
                    masked_data = masked_img.get_fdata()
                
                num_slices = img_data.shape[2]

                # Determine the number of channels for the output array
                num_channels = 2 if contour_exists else 1
                
                # Initialize an array to store combined slices
                combined_slices = np.zeros((img_data.shape[0], img_data.shape[1], num_slices, num_channels)) 

                # Loop through each slice and assign image and mask (if exists)
                for i in range(num_slices):
                    combined_slices[:, :, i, 0] = img_data[:, :, i]  # Assign the image slice
                    if contour_exists:
                        combined_slices[:, :, i, 1] = masked_data[:, :, i]  # Assign the mask slice

                # Directory to save the combined slices
                output_directory = os.path.join(patient_path, 'Slices')
                os.makedirs(output_directory, exist_ok=True)  # Create the directory if it doesn't exist

                # Loop through each slice and save it
                for i in range(num_slices):
                    if contour_exists:
                        # Create a new array to hold both the image and contour
                        combined_slice = np.zeros((img_data.shape[0], img_data.shape[1], 2))  # Shape: (height, width, 2)
                        
                        # Assign the image and contour to the new array
                        combined_slice[:, :, 0] = combined_slices[:, :, i, 0]  # Image slice
                        combined_slice[:, :, 1] = combined_slices[:, :, i, 1]  # Contour slice
                        
                        # Determine the infarction value based on the dataset folder name
                        parent_folder = os.path.basename(subfolder_path)  # Get the name of the parent folder
                        if parent_folder.startswith('EMIDEC'):
                            infarction_value = 3
                        elif parent_folder.startswith('MyoPS'):
                            infarction_value = 1220
                        else:
                            infarction_value = None  # Handle unexpected cases if needed

                        # Check for infarction and no-reflow
                        if infarction_value is not None and np.any(combined_slice[:, :, 1] == infarction_value):
                            slice_filename = f'{patient_folder}_slice_{i+1}_Inf_NoReflowN.npy'
                            if np.any(combined_slice[:, :, 1] == 4): 
                                slice_filename = f'{patient_folder}_slice_{i+1}_Inf_NoReflowY.npy'
                        else:
                            slice_filename = f'{patient_folder}_slice_{i+1}_NoInf_NoReflowN.npy'
                            if np.any(combined_slice[:, :, 1] == 4):  
                                slice_filename = f'{patient_folder}_slice_{i+1}_NoInf_NoReflowY.npy'

                    else:
                        # Only include the image slice if no contour is available
                        combined_slice = np.zeros((img_data.shape[0], img_data.shape[1], 1))  # Shape: (height, width, 1)
                        combined_slice[:, :, 0] = combined_slices[:, :, i, 0]  # Image slice
                        slice_filename = f'{patient_folder}_slice_{i+1}.npy'

                    # Save the combined slice as .npy file
                    np.save(os.path.join(output_directory, slice_filename), combined_slice)

                print(f'Combined slices for {patient_folder} saved successfully.')
# Out:
# Processing patient: Case_101
# Combined slices for Case_101 saved successfully.
# Processing patient: Case_102
# Combined slices for Case_102 saved successfully.
# Processing patient: Case_103
# Combined slices for Case_103 saved successfully.
# Processing patient: Case_104
# Combined slices for Case_104 saved successfully.
# Processing patient: Case_105
# Combined slices for Case_105 saved successfully.
# Processing patient: Case_106
# Combined slices for Case_106 saved successfully.
# Processing patient: Case_107
# Combined slices for Case_107 saved successfully.
# Processing patient: Case_108
# Combined slices for Case_108 saved successfully.
# Processing patient: Case_109
# Combined slices for Case_109 saved successfully.
# Processing patient: Case_110
# Combined slices for Case_110 saved successfully.
# Processing patient: Case_111
# Combined slices for Case_111 saved successfully.
# Processing patient: Case_112
# Combined slices for Case_112 saved successfully.
# Processing patient: Case_113
# Combined slices for Case_113 saved successfully.
# Processing patient: Case_114
# Combined slices for Case_114 saved successfully.
# Processing patient: Case_115
# Combined slices for Case_115 saved successfully.
# Processing patient: Case_116
# Combined slices for Case_116 saved successfully.
# Processing patient: Case_117
# Combined slices for Case_117 saved successfully.
# Processing patient: Case_118
# Combined slices for Case_118 saved successfully.
# Processing patient: Case_119
# Combined slices for Case_119 saved successfully.
# Processing patient: Case_120
# Combined slices for Case_120 saved successfully.
# Processing patient: Case_121
# Combined slices for Case_121 saved successfully.
# Processing patient: Case_122
# Combined slices for Case_122 saved successfully.
# Processing patient: Case_123
# Combined slices for Case_123 saved successfully.
# Processing patient: Case_124
# Combined slices for Case_124 saved successfully.
# Processing patient: Case_125
# Combined slices for Case_125 saved successfully.
# Processing patient: Case_126
# Combined slices for Case_126 saved successfully.
# Processing patient: Case_127
# Combined slices for Case_127 saved successfully.
# Processing patient: Case_128
# Combined slices for Case_128 saved successfully.
# Processing patient: Case_129
# Combined slices for Case_129 saved successfully.
# Processing patient: Case_130
# Combined slices for Case_130 saved successfully.
# Processing patient: Case_131
# Combined slices for Case_131 saved successfully.
# Processing patient: Case_132
# Combined slices for Case_132 saved successfully.
# Processing patient: Case_133
# Combined slices for Case_133 saved successfully.
# Processing patient: Case_134
# Combined slices for Case_134 saved successfully.
# Processing patient: Case_135
# Combined slices for Case_135 saved successfully.
# Processing patient: Case_136
# Combined slices for Case_136 saved successfully.
# Processing patient: Case_137
# Combined slices for Case_137 saved successfully.
# Processing patient: Case_138
# Combined slices for Case_138 saved successfully.
# Processing patient: Case_139
# Combined slices for Case_139 saved successfully.
# Processing patient: Case_140
# Combined slices for Case_140 saved successfully.
# Processing patient: Case_141
# Combined slices for Case_141 saved successfully.
# Processing patient: Case_142
# Combined slices for Case_142 saved successfully.
# Processing patient: Case_143
# Combined slices for Case_143 saved successfully.
# Processing patient: Case_144
# Combined slices for Case_144 saved successfully.
# Processing patient: Case_145
# Combined slices for Case_145 saved successfully.
# Processing patient: Case_146
# Combined slices for Case_146 saved successfully.
# Processing patient: Case_147
# Combined slices for Case_147 saved successfully.
# Processing patient: Case_148
# Combined slices for Case_148 saved successfully.
# Processing patient: Case_149
# Combined slices for Case_149 saved successfully.
# Processing patient: Case_150
# Combined slices for Case_150 saved successfully.
# Processing patient: Case_N006
# Combined slices for Case_N006 saved successfully.
# Processing patient: Case_N012
# Combined slices for Case_N012 saved successfully.
# Processing patient: Case_N013
# Combined slices for Case_N013 saved successfully.
# Processing patient: Case_N014
# Combined slices for Case_N014 saved successfully.
# Processing patient: Case_N016
# Combined slices for Case_N016 saved successfully.
# Processing patient: Case_N018
# Combined slices for Case_N018 saved successfully.
# Processing patient: Case_N020
# Combined slices for Case_N020 saved successfully.
# Processing patient: Case_N023
# Combined slices for Case_N023 saved successfully.
# Processing patient: Case_N024
# Combined slices for Case_N024 saved successfully.
# Processing patient: Case_N025
# Combined slices for Case_N025 saved successfully.
# Processing patient: Case_N027
# Combined slices for Case_N027 saved successfully.
# Processing patient: Case_N030
# Combined slices for Case_N030 saved successfully.
# Processing patient: Case_N032
# Combined slices for Case_N032 saved successfully.
# Processing patient: Case_N033
# Combined slices for Case_N033 saved successfully.
# Processing patient: Case_N034
# Combined slices for Case_N034 saved successfully.
# Processing patient: Case_N037
# Combined slices for Case_N037 saved successfully.
# Processing patient: Case_N040
# Combined slices for Case_N040 saved successfully.
# Processing patient: Case_N041
# Combined slices for Case_N041 saved successfully.
# Processing patient: Case_N042
# Combined slices for Case_N042 saved successfully.
# Processing patient: Case_N046
# Combined slices for Case_N046 saved successfully.
# Processing patient: Case_N048
# Combined slices for Case_N048 saved successfully.
# Processing patient: Case_N049
# Combined slices for Case_N049 saved successfully.
# Processing patient: Case_N052
# Combined slices for Case_N052 saved successfully.
# Processing patient: Case_N054
# Combined slices for Case_N054 saved successfully.
# Processing patient: Case_N058
# Combined slices for Case_N058 saved successfully.
# Processing patient: Case_N065
# Combined slices for Case_N065 saved successfully.
# Processing patient: Case_N068
# Combined slices for Case_N068 saved successfully.
# Processing patient: Case_N070
# Combined slices for Case_N070 saved successfully.
# Processing patient: Case_N075
# Combined slices for Case_N075 saved successfully.
# Processing patient: Case_N079
# Combined slices for Case_N079 saved successfully.
# Processing patient: Case_N083
# Combined slices for Case_N083 saved successfully.
# Processing patient: Case_N084
# Combined slices for Case_N084 saved successfully.
# Processing patient: Case_N089
# Combined slices for Case_N089 saved successfully.
# Processing patient: Case_P001
# Combined slices for Case_P001 saved successfully.
# Processing patient: Case_P002
# Combined slices for Case_P002 saved successfully.
# Processing patient: Case_P003
# Combined slices for Case_P003 saved successfully.
# Processing patient: Case_P004
# Combined slices for Case_P004 saved successfully.
# Processing patient: Case_P005
# Combined slices for Case_P005 saved successfully.
# Processing patient: Case_P007
# Combined slices for Case_P007 saved successfully.
# Processing patient: Case_P008
# Combined slices for Case_P008 saved successfully.
# Processing patient: Case_P009
# Combined slices for Case_P009 saved successfully.
# Processing patient: Case_P010
# Combined slices for Case_P010 saved successfully.
# Processing patient: Case_P011
# Combined slices for Case_P011 saved successfully.
# Processing patient: Case_P015
# Combined slices for Case_P015 saved successfully.
# Processing patient: Case_P017
# Combined slices for Case_P017 saved successfully.
# Processing patient: Case_P019
# Combined slices for Case_P019 saved successfully.
# Processing patient: Case_P021
# Combined slices for Case_P021 saved successfully.
# Processing patient: Case_P022
# Combined slices for Case_P022 saved successfully.
# Processing patient: Case_P026
# Combined slices for Case_P026 saved successfully.
# Processing patient: Case_P028
# Combined slices for Case_P028 saved successfully.
# Processing patient: Case_P029
# Combined slices for Case_P029 saved successfully.
# Processing patient: Case_P031
# Combined slices for Case_P031 saved successfully.
# Processing patient: Case_P035
# Combined slices for Case_P035 saved successfully.
# Processing patient: Case_P036
# Combined slices for Case_P036 saved successfully.
# Processing patient: Case_P038
# Combined slices for Case_P038 saved successfully.
# Processing patient: Case_P039
# Combined slices for Case_P039 saved successfully.
# Processing patient: Case_P043
# Combined slices for Case_P043 saved successfully.
# Processing patient: Case_P044
# Combined slices for Case_P044 saved successfully.
# Processing patient: Case_P045
# Combined slices for Case_P045 saved successfully.
# Processing patient: Case_P047
# Combined slices for Case_P047 saved successfully.
# Processing patient: Case_P050
# Combined slices for Case_P050 saved successfully.
# Processing patient: Case_P051
# Combined slices for Case_P051 saved successfully.
# Processing patient: Case_P053
# Combined slices for Case_P053 saved successfully.
# Processing patient: Case_P055
# Combined slices for Case_P055 saved successfully.
# Processing patient: Case_P056
# Combined slices for Case_P056 saved successfully.
# Processing patient: Case_P057
# Combined slices for Case_P057 saved successfully.
# Processing patient: Case_P059
# Combined slices for Case_P059 saved successfully.
# Processing patient: Case_P060
# Combined slices for Case_P060 saved successfully.
# Processing patient: Case_P061
# Combined slices for Case_P061 saved successfully.
# Processing patient: Case_P062
# Combined slices for Case_P062 saved successfully.
# Processing patient: Case_P063
# Combined slices for Case_P063 saved successfully.
# Processing patient: Case_P064
# Combined slices for Case_P064 saved successfully.
# Processing patient: Case_P066
# Combined slices for Case_P066 saved successfully.
# Processing patient: Case_P067
# Combined slices for Case_P067 saved successfully.
# Processing patient: Case_P069
# Combined slices for Case_P069 saved successfully.
# Processing patient: Case_P071
# Combined slices for Case_P071 saved successfully.
# Processing patient: Case_P072
# Combined slices for Case_P072 saved successfully.
# Processing patient: Case_P073
# Combined slices for Case_P073 saved successfully.
# Processing patient: Case_P074
# Combined slices for Case_P074 saved successfully.
# Processing patient: Case_P076
# Combined slices for Case_P076 saved successfully.
# Processing patient: Case_P077
# Combined slices for Case_P077 saved successfully.
# Processing patient: Case_P078
# Combined slices for Case_P078 saved successfully.
# Processing patient: Case_P080
# Combined slices for Case_P080 saved successfully.
# Processing patient: Case_P081
# Combined slices for Case_P081 saved successfully.
# Processing patient: Case_P082
# Combined slices for Case_P082 saved successfully.
# Processing patient: Case_P085
# Combined slices for Case_P085 saved successfully.
# Processing patient: Case_P086
# Combined slices for Case_P086 saved successfully.
# Processing patient: Case_P087
# Combined slices for Case_P087 saved successfully.
# Processing patient: Case_P088
# Combined slices for Case_P088 saved successfully.
# Processing patient: Case_P090
# Combined slices for Case_P090 saved successfully.
# Processing patient: Case_P091
# Combined slices for Case_P091 saved successfully.
# Processing patient: Case_P092
# Combined slices for Case_P092 saved successfully.
# Processing patient: Case_P093
# Combined slices for Case_P093 saved successfully.
# Processing patient: Case_P094
# Combined slices for Case_P094 saved successfully.
# Processing patient: Case_P095
# Combined slices for Case_P095 saved successfully.
# Processing patient: Case_P096
# Combined slices for Case_P096 saved successfully.
# Processing patient: Case_P097
# Combined slices for Case_P097 saved successfully.
# Processing patient: Case_P098
# Combined slices for Case_P098 saved successfully.
# Processing patient: Case_P099
# Combined slices for Case_P099 saved successfully.
# Processing patient: Case_P100
# Combined slices for Case_P100 saved successfully.
# Processing patient: Case_201
# Combined slices for Case_201 saved successfully.
# Processing patient: Case_202
# Combined slices for Case_202 saved successfully.
# Processing patient: Case_203
# Combined slices for Case_203 saved successfully.
# Processing patient: Case_204
# Combined slices for Case_204 saved successfully.
# Processing patient: Case_205
# Combined slices for Case_205 saved successfully.
# Processing patient: Case_206
# Combined slices for Case_206 saved successfully.
# Processing patient: Case_207
# Combined slices for Case_207 saved successfully.
# Processing patient: Case_208
# Combined slices for Case_208 saved successfully.
# Processing patient: Case_209
# Combined slices for Case_209 saved successfully.
# Processing patient: Case_210
# Combined slices for Case_210 saved successfully.
# Processing patient: Case_211
# Combined slices for Case_211 saved successfully.
# Processing patient: Case_212
# Combined slices for Case_212 saved successfully.
# Processing patient: Case_213
# Combined slices for Case_213 saved successfully.
# Processing patient: Case_214
# Combined slices for Case_214 saved successfully.
# Processing patient: Case_215
# Combined slices for Case_215 saved successfully.
# Processing patient: Case_216
# Combined slices for Case_216 saved successfully.
# Processing patient: Case_217
# Combined slices for Case_217 saved successfully.
# Processing patient: Case_218
# Combined slices for Case_218 saved successfully.
# Processing patient: Case_219
# Combined slices for Case_219 saved successfully.
# Processing patient: Case_220
# Combined slices for Case_220 saved successfully.
# Processing patient: Case_P101
# Combined slices for Case_P101 saved successfully.
# Processing patient: Case_P102
# Combined slices for Case_P102 saved successfully.
# Processing patient: Case_P103
# Combined slices for Case_P103 saved successfully.
# Processing patient: Case_P104
# Combined slices for Case_P104 saved successfully.
# Processing patient: Case_P105
# Combined slices for Case_P105 saved successfully.
# Processing patient: Case_P106
# Combined slices for Case_P106 saved successfully.
# Processing patient: Case_P107
# Combined slices for Case_P107 saved successfully.
# Processing patient: Case_P108
# Combined slices for Case_P108 saved successfully.
# Processing patient: Case_P109
# Combined slices for Case_P109 saved successfully.
# Processing patient: Case_P110
# Combined slices for Case_P110 saved successfully.
# Processing patient: Case_P111
# Combined slices for Case_P111 saved successfully.
# Processing patient: Case_P112
# Combined slices for Case_P112 saved successfully.
# Processing patient: Case_P113
# Combined slices for Case_P113 saved successfully.
# Processing patient: Case_P114
# Combined slices for Case_P114 saved successfully.
# Processing patient: Case_P115
# Combined slices for Case_P115 saved successfully.
# Processing patient: Case_P116
# Combined slices for Case_P116 saved successfully.
# Processing patient: Case_P117
# Combined slices for Case_P117 saved successfully.
# Processing patient: Case_P118
# Combined slices for Case_P118 saved successfully.
# Processing patient: Case_P119
# Combined slices for Case_P119 saved successfully.
# Processing patient: Case_P120
# Combined slices for Case_P120 saved successfully.
# Processing patient: Case_P121
# Combined slices for Case_P121 saved successfully.
# Processing patient: Case_P122
# Combined slices for Case_P122 saved successfully.
# Processing patient: Case_P123
# Combined slices for Case_P123 saved successfully.
# Processing patient: Case_P124
# Combined slices for Case_P124 saved successfully.
# Processing patient: Case_P125
# Combined slices for Case_P125 saved successfully.
