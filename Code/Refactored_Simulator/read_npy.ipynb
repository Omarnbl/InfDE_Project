# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the data in the npy file
base_path = r"E:\SBME\Graduation Project\Datasets\Simulated_data\merged"
data = np.load(base_path + r"\merged_mask_3.npy")
# visualize the data
plt.imshow(data, cmap='gray')
plt.show()
# print the unique values in the data
print(np.unique(data))
print(data.shape)
# Out:
# [0 2 3]
# (128, 128)
